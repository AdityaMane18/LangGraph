# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI()

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    #fetch title
    title = state['title']
    #call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content
    #update state
    state['outline'] = outline
    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the following outline \n {outline}'

    content =model.invoke(prompt).content
    state['content'] = content
    return state

# %%
graph = StateGraph(BlogState)

#nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

#edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
initial_state = {'title': "Rise of AI in India"}
final_state = workflow.invoke(initial_state)
print(final_state['content'])
# Out:
# I. Introduction
#
# A. Definition of AI (Artificial Intelligence)
# Artificial Intelligence (AI) is the capability of machines to imitate intelligent human behavior, such as learning from experience, recognizing speech, interpreting images, and making decisions. It involves the development of computer systems that can perform tasks that typically require human intelligence.
#
# B. Brief overview of AI technology
# AI technology encompasses a range of techniques such as machine learning, deep learning, natural language processing, and robotics. These technologies are increasingly being used in various industries to automate processes, improve efficiency, and drive innovation.
#
# C. Importance of AI in India
# In India, AI is playing a crucial role in driving digital transformation and supporting the government's initiatives such as Digital India and Make in India. The adoption of AI technology has the potential to revolutionize various sectors and drive economic growth in the country.
#
# II. History of AI in India
#
# A. Early developments in AI technology in India
# India has a rich history in the field of AI, with research and development efforts dating back to the 1960s. Institutions such as the Indian Institute of Technology (IIT), Indian Statistical Institute (ISI), and the Defense Research and Development Organization (DRDO) have contributed significantly to the advancement of AI technology in India.
#
# B. Adoption of AI in various industries in India
# Over the years, AI technology has been widely adopted in various industries in India, including healthcare, agriculture, financial services, and manufacturing. Companies are increasingly leveraging AI solutions to improve operational efficiency, enhance customer experience, and drive innovation.
#
# C. Growth of AI startups in India
# India has seen a surge in the number of AI startups in recent years, with a focus on developing cutting-edge solutions in areas such as healthcare, education, e-commerce, and cybersecurity. These startups are attracting investments from both domestic and international investors, fueling the growth of the AI industry in India.
#
# III. Current landscape of AI in India
#
# A. Key players in the AI industry in India
# Some of the key players in the AI industry in India include multinational companies like Google, Microsoft, and IBM, as well as homegrown startups such as Flipkart, Zomato, and Ola. These companies are leveraging AI technology to drive innovation and gain a competitive edge in the market.
#
# B. Government initiatives to promote AI technology
# The Indian government has launched various initiatives to promote AI technology, such as the National AI Portal and the National Program on AI. These initiatives aim to foster collaboration between industry, academia, and government to accelerate the adoption of AI technology in the country.
#
# C. Investments in AI technology in India
# India has seen a significant increase in investments in AI technology, with venture capital funds, corporate investors, and government agencies funding AI startups and research projects. This influx of capital is fueling the growth of the AI industry and driving innovation in the country.
#
# IV. Applications of AI in India
#
# A. AI in healthcare sector
# AI technology is being used in the healthcare sector to improve diagnostics, personalize treatment plans, and enhance patient care. Applications of AI in healthcare include medical imaging, predictive analytics, and virtual health assistants.
#
# B. AI in agriculture sector
# In the agriculture sector, AI technology is being used to optimize crop yields, monitor soil health, and manage resources efficiently. AI solutions such as precision agriculture and smart farming are helping farmers make data-driven decisions and improve productivity.
#
# C. AI in financial services sector
# AI technology is transforming the financial services sector by enabling automation, fraud detection, and personalized banking services. Applications of AI in finance include algorithmic trading, robo-advisors, and chatbots for customer service.
#
# D. AI in manufacturing sector
# The manufacturing sector in India is increasingly adopting AI technology to automate processes, improve quality control, and optimize production. AI solutions such as predictive maintenance, robotic automation, and supply chain management are revolutionizing the manufacturing industry in India.
#
# V. Challenges and opportunities for AI in India
#
# A. Lack of skilled professionals in AI technology
# One of the key challenges facing the AI industry in India is the shortage of skilled professionals with expertise in AI technology. There is a growing demand for AI talent in the country, and efforts are being made to bridge the skills gap through education and training programs.
#
# B. Data privacy and security concerns
# Data privacy and security concerns are another challenge for the AI industry in India, particularly with the increasing use of AI technologies that rely on vast amounts of data. It is essential for organizations to prioritize data protection and adhere to regulations to build trust with consumers.
#
# C. Opportunities for growth and innovation in AI technology in India
# Despite the challenges, there are vast opportunities for growth and innovation in the AI industry in India. With a large pool of technical talent, a supportive ecosystem for startups, and increasing investments in AI technology, the country is well-positioned to become a global hub for AI innovation.
#
# VI. Future prospects of AI in India
#
# A. Predictions for the growth of AI technology in India
# The future prospects for AI in India are promising, with projections for continued growth and adoption of AI technology across industries. As organizations embrace AI solutions to drive efficiency and innovation, the AI industry in India is expected to expand rapidly in the coming years.
#
# B. Potential impact of AI on Indian economy and society
# AI technology has the potential to have a transformative impact on the Indian economy and society, driving productivity, creating new job opportunities, and improving quality of life. The adoption of AI solutions can help address societal challenges and drive inclusive growth in the country.
#
# C. Strategies for harnessing the potential of AI in India
# To harness the full potential of AI technology in India, stakeholders across government, industry, and academia need to collaborate and invest in research, education, and infrastructure. By fostering a supportive ecosystem for AI innovation, India can position itself as a global leader in AI technology.
#
# VII. Conclusion
#
# A. Recap of key points discussed in the blog
# In conclusion, the rise of AI in India presents a significant opportunity for economic growth, innovation, and societal impact. The country's rich history in AI technology, coupled with the growing adoption of AI solutions across industries, positions India as a key player in the global AI landscape.
#
# B. Call to action for stakeholders in the AI industry in India
# Stakeholders in the AI industry in India, including government, industry players, investors, and academia, have a crucial role to play in driving the growth and adoption of AI technology. Collaboration and strategic investments are essential to capitalize on the opportunities presented by AI.
#
# C. Final thoughts on the rise of AI in India
# As India continues to embrace AI technology and drive innovation in the field, the country has the potential to become a powerhouse in AI technology, contributing to global advancements in AI research and applications. The rise of AI in India represents a key milestone in the country's journey towards becoming a digital hub in the modern era.
