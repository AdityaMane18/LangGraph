# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()

llm = ChatOpenAI()

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza go to the doctor? Because it was feeling a little crusty!',
#  'explanation': 'This joke is a play on words, using the term "crusty" in two different contexts. In the context of pizza, "crusty" refers to the texture of the outer layer of the pizza crust. In the context of feeling unwell, "crusty" is often used to describe someone feeling tired, irritable, or generally unwell.\n\nSo, the joke is saying that the pizza went to the doctor because it was feeling a little "crusty" in terms of its texture (crust) but also implying that it was feeling unwell or run down. It\'s a humorous way to personify the pizza and create a pun out of its physical characteristics.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? Because it was feeling a little crusty!', 'explanation': 'This joke is a play on words, using the term "crusty" in two different contexts. In the context of pizza, "crusty" refers to the texture of the outer layer of the pizza crust. In the context of feeling unwell, "crusty" is often used to describe someone feeling tired, irritable, or generally unwell.\n\nSo, the joke is saying that the pizza went to the doctor because it was feeling a little "crusty" in terms of its texture (crust) but also implying that it was feeling unwell or run down. It\'s a humorous way to personify the pizza and create a pun out of its physical characteristics.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f3d21-bf2e-677d-8002-d3dc69512768'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-17T18:26:58.607090+00:00', parent_config={'configurable'
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? Because it was feeling a little crusty!', 'explanation': 'This joke is a play on words, using the term "crusty" in two different contexts. In the context of pizza, "crusty" refers to the texture of the outer layer of the pizza crust. In the context of feeling unwell, "crusty" is often used to describe someone feeling tired, irritable, or generally unwell.\n\nSo, the joke is saying that the pizza went to the doctor because it was feeling a little "crusty" in terms of its texture (crust) but also implying that it was feeling unwell or run down. It\'s a humorous way to personify the pizza and create a pun out of its physical characteristics.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f3d21-bf2e-677d-8002-d3dc69512768'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-17T18:26:58.607090+00:00', parent_config={'configurable
# ...

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti go to the party? Because it heard it was going to be a pasta-farian celebration!',
#  'explanation': 'This joke is a play on words combining the term "pasta" with "Pastafarian," which is a term used to describe followers of the parody religion called the Church of the Flying Spaghetti Monster. The joke implies that the spaghetti went to the party because it thought it was going to be a celebration of its own kind, a reference to the followers of the Church of the Flying Spaghetti Monster who humorously believe in a flying spaghetti monster as their deity.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? Because it was feeling a little crusty!', 'explanation': 'This joke is a play on words, using the term "crusty" in two different contexts. In the context of pizza, "crusty" refers to the texture of the outer layer of the pizza crust. In the context of feeling unwell, "crusty" is often used to describe someone feeling tired, irritable, or generally unwell.\n\nSo, the joke is saying that the pizza went to the doctor because it was feeling a little "crusty" in terms of its texture (crust) but also implying that it was feeling unwell or run down. It\'s a humorous way to personify the pizza and create a pun out of its physical characteristics.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f3d21-bf2e-677d-8002-d3dc69512768'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-17T18:26:58.607090+00:00', parent_config={'configurable'
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? Because it was feeling a little crusty!', 'explanation': 'This joke is a play on words, using the term "crusty" in two different contexts. In the context of pizza, "crusty" refers to the texture of the outer layer of the pizza crust. In the context of feeling unwell, "crusty" is often used to describe someone feeling tired, irritable, or generally unwell.\n\nSo, the joke is saying that the pizza went to the doctor because it was feeling a little "crusty" in terms of its texture (crust) but also implying that it was feeling unwell or run down. It\'s a humorous way to personify the pizza and create a pun out of its physical characteristics.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f3d21-bf2e-677d-8002-d3dc69512768'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-17T18:26:58.607090+00:00', parent_config={'configurable
# ...

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f0f3d21-9ec5-60bd-8001-bbcd96d82a21"}})
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? Because it was feeling a little crusty!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f0f3d21-9ec5-60bd-8001-bbcd96d82a21'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-01-17T18:26:55.208466+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f3d21-8faf-6b9c-8000-4b01c579c94e'}}, tasks=(PregelTask(id='a5aaa134-3e72-3099-4f97-c21f0825cdf5', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a play on words, using the term "crusty" in two different contexts. In the context of pizza, "crusty" refers to the texture of the outer layer of the pizza crust. In the context of feeling unwell, "crusty" is often used to describe someone feeling tired, irritable, or generally unwell.\n\n
# ...

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f0f3d21-9ec5-60bd-8001-bbcd96d82a21"}})
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza go to the doctor? Because it was feeling a little crusty!',
#  'explanation': 'This joke plays on the double meaning of the word "crusty." In one sense, crusty refers to the outer edge of a pizza. In another sense, crusty can mean something that is old, unwell, or in poor condition. By saying the pizza went to the doctor because it was feeling a little crusty, the joke implies that the pizza was not in good shape and needed medical attention, while also referencing its pizza crust. This creates a humorous play on words and a silly image of a pizza seeking medical help.'}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? Because it was feeling a little crusty!', 'explanation': 'This joke plays on the double meaning of the word "crusty." In one sense, crusty refers to the outer edge of a pizza. In another sense, crusty can mean something that is old, unwell, or in poor condition. By saying the pizza went to the doctor because it was feeling a little crusty, the joke implies that the pizza was not in good shape and needed medical attention, while also referencing its pizza crust. This creates a humorous play on words and a silly image of a pizza seeking medical help.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f3d27-7295-6de1-8002-f17660f20943'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-17T18:29:31.636681+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f3d21-9ec5-60bd-8001-bbcd96d
# ...

# %%
workflow.update_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f0f3d21-9ec5-60bd-8001-bbcd96d82a21", "checkpoint_ns": ""}}, {'topic':'samosa'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0f3d28-84fe-61f8-8002-fd0204bbc450'}}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa', 'joke': 'Why did the pizza go to the doctor? Because it was feeling a little crusty!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f3d28-84fe-61f8-8002-fd0204bbc450'}}, metadata={'source': 'update', 'step': 2, 'parents': {}}, created_at='2026-01-17T18:30:00.410367+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f3d21-9ec5-60bd-8001-bbcd96d82a21'}}, tasks=(PregelTask(id='eb281145-da87-83fb-648d-765cba80c671', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f0f3d21-9ec5-60bd-8001-bbcd96d82a21"}})
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza go to the doctor? Because it was feeling a little crusty!',
#  'explanation': 'This joke plays on the double meaning of the word "crusty." In the context of pizza, "crusty" typically refers to the outer layer of the crust, which is often crispy and slightly burnt. However, "crusty" can also be used to describe someone or something that is grumpy or irritable. So, when the joke says that the pizza went to the doctor because it was feeling a little crusty, it is using wordplay to suggest that the pizza was not only physically crusty but also in a bad mood or feeling unwell.'}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? Because it was feeling a little crusty!', 'explanation': 'This joke plays on the double meaning of the word "crusty." In the context of pizza, "crusty" typically refers to the outer layer of the crust, which is often crispy and slightly burnt. However, "crusty" can also be used to describe someone or something that is grumpy or irritable. So, when the joke says that the pizza went to the doctor because it was feeling a little crusty, it is using wordplay to suggest that the pizza was not only physically crusty but also in a bad mood or feeling unwell.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f3d29-a463-60c7-8002-c222dc3e1514'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-17T18:30:30.545837+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f3d21-9ec5-60bd-8001-bbcd
# ...
